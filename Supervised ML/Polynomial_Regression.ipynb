# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
dataset = pd.read_csv("level_salary_dataset.csv")

# %%
dataset
# Out:
#      Level   Salary
# 0        1    11780
# 1        2     6900
# 2        3    12980
# 3        4    14351
# 4        5    16484
# ..     ...      ...
# 495    496  3208282
# 496    497  3222669
# 497    498  3231611
# 498    499  3246583
# 499    500  3258104
#
# [500 rows x 2 columns]

# %%
plt.figure(figsize= (5, 4))
sns.scatterplot(x="Level", y="Salary", data=dataset)
plt.show()

# %%
x = dataset[["Level"]]
y = dataset["Salary"]

# %% [markdown]
# ##### Change into the Polynomial Features with degree = 2

# %%
pf = PolynomialFeatures(degree=2)
pf.fit(x)
x = pf.transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100   # Accuracy of model
# Out:
# 99.99926118735412

# %%
y_pred = lr.predict(x)  # Prediction on entire data

# %%
plt.figure(figsize=(5, 4))
plt.plot(dataset["Level"], y_pred, c='r')
sns.scatterplot(x="Level", y="Salary", data=dataset)
plt.legend({"Predicted", "Original"})
plt.show()

# %% [markdown]
# ### for new input data

# %%
test = pf.transform([[40]])
test
# Out:
# C:\Users\Anshil\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1.0e+00, 4.0e+01, 1.6e+03]])

# %%
lr.predict(test)
# Out:
# array([84114.12475296])
