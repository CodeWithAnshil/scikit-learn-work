# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import precision_score

# %%
dataset = pd.read_csv("placement_data.csv")

# %%
dataset.head(2)
# Out:
#    CGPA  Score  Placement
# 0  6.87    211          0
# 1  9.75    517          1

# %%
sns.scatterplot(x="CGPA", y="Score", data=dataset, hue="Placement")
plt.show()

# %%
sns.kdeplot(data=dataset["CGPA"])
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["Placement"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # GaussianNB Algorithm

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test, y_test)*100
# Out:
# 95.0

# %%
y_pred = gnb.predict(x_test)

# %%
precision_score(y_test, y_pred)*100
# Out:
# 100.0

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=gnb)
# Out:
# C:\Users\Anshil\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# # MultinomialNB Algorithm

# %%
mnb = MultinomialNB()
mnb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_test, y_test)*100 # MNB is not good for this
# Out:
# 61.5

# %% [markdown]
# # BernoulliNB Algorithm

# %%
bnb = BernoulliNB()
bnb.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
bnb.score(x_test, y_test)*100
# Out:
# 68.0
