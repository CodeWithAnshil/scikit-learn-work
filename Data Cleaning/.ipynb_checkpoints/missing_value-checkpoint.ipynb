# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Diabetes Missing Data.csv")

# %%
dataset.head(3)
dataset.shape[0]
# Out:
# 768

# %%
dataset.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
(dataset.isnull().sum()/(dataset.shape[0]))*100
# Out:
# Pregnant              0.000000
# Glucose               0.651042
# Diastolic_BP          4.557292
# Skin_Fold            29.557292
# Serum_Insulin        48.697917
# BMI                   1.432292
# Diabetes_Pedigree     0.000000
# Age                   0.000000
# Class                 0.000000
# dtype: float64

# %%
missing_per=(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
missing_per
# Out:
# 9.43287037037037

# %%
notnull=dataset.notnull()
# Out:
# 6260

# %%
sns.heatmap(dataset.isnull())
plt.show()
