# %% [markdown]
# # Linear Regression Algorithm

# %%
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split  
from sklearn import linear_model

# %%
housing = fetch_california_housing()
X, y = housing.data, housing.target

# %%
X.shape
# Out:
# (20640, 8)

# %%
y.shape
# Out:
# (20640,)

# %%
plt.scatter(X[:,3],y)
plt.show()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
l_reg=linear_model.LinearRegression()
model=l_reg.fit(X_train,y_train)

# %%
l_pred=model.predict(X_test)

# %%
l_pred
# Out:
# array([2.24701967, 2.66685763, 2.50172253, ..., 2.62982818, 2.25512184,
#        3.10442386])

# %%
plt.scatter(l_pred,y_test)

# %%
print("Accuracy/R^2",l_reg.score(X,y))
# Out:
# Accuracy/R^2 0.6038376671237777

# %%
print("Linear Regression Coefficient",l_reg.coef_)
# Out:
# Linear Regression Coefficient [ 4.42290520e-01  9.56900752e-03 -1.13661014e-01  7.43087453e-01
#   2.47827818e-07 -8.19378554e-03 -4.25712801e-01 -4.40386376e-01]

# %%
print("y_intercept",l_reg.intercept_)
# Out:
# y_intercept -37.573485664077246
