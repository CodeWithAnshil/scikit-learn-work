# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CSV/kidney_disease.csv')

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]

# %%
len(df.columns)
# Out:
# 26

# %%
# df.dtypes

# %%
# df.isnull().sum()

# %%
df['pcv'] = pd.to_numeric(df['pcv'], errors='coerce')

# %%
df['wc'] = pd.to_numeric(df['wc'], errors='coerce')
df['rc'] = pd.to_numeric(df['rc'], errors='coerce')

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                float64
# rc                float64
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
# for col in df:
#     cat_col df[col].dtype=='object'

# %%
cat_col= [features for features in df.columns if df[features].dtype=='object']
num_col= [features for features in df.columns if df[features].dtype!='object']

# %%
for col in cat_col:
     print(f"Feature '{col}' has {df[col].nunique()} unique values: {df[col].unique()}")
# Out:
# Feature 'rbc' has 2 unique values: [nan 'normal' 'abnormal']
# Feature 'pc' has 2 unique values: ['normal' 'abnormal' nan]
# Feature 'pcc' has 2 unique values: ['notpresent' 'present' nan]
# Feature 'ba' has 2 unique values: ['notpresent' 'present' nan]
# Feature 'htn' has 2 unique values: ['yes' 'no' nan]
# Feature 'dm' has 5 unique values: ['yes' 'no' ' yes' '\tno' '\tyes' nan]
# Feature 'cad' has 3 unique values: ['no' 'yes' '\tno' nan]
# Feature 'appet' has 2 unique values: ['good' 'poor' nan]
# Feature 'pe' has 2 unique values: ['no' 'yes' nan]
# Feature 'ane' has 2 unique values: ['no' 'yes' nan]
# Feature 'classification' has 3 unique values: ['ckd' 'ckd\t' 'notckd']

# %%
columns=['dm', 'cad','classification']
for col in columns:
    df[col].replace(to_replace={' yes':'yes','\tno':'no','\tyes':'yes','ckd\t':'ckd'},inplace=True)
# Out:
# C:\Users\Anshil\AppData\Local\Temp\ipykernel_15544\224129567.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace(to_replace={' yes':'yes','\tno':'no','\tyes':'yes','ckd\t':'ckd'},inplace=True)

# %%
df['rbc'].value_counts()
# Out:
# rbc
# normal      201
# abnormal     47
# Name: count, dtype: int64

# %%
for col in cat_col:
     print(f"Feature '{col}' has {df[col].nunique()} unique values: {df[col].unique()}")
# Out:
# Feature 'rbc' has 2 unique values: [nan 'normal' 'abnormal']
# Feature 'pc' has 2 unique values: ['normal' 'abnormal' nan]
# Feature 'pcc' has 2 unique values: ['notpresent' 'present' nan]
# Feature 'ba' has 2 unique values: ['notpresent' 'present' nan]
# Feature 'htn' has 2 unique values: ['yes' 'no' nan]
# Feature 'dm' has 2 unique values: ['yes' 'no' nan]
# Feature 'cad' has 2 unique values: ['no' 'yes' nan]
# Feature 'appet' has 2 unique values: ['good' 'poor' nan]
# Feature 'pe' has 2 unique values: ['no' 'yes' nan]
# Feature 'ane' has 2 unique values: ['no' 'yes' nan]
# Feature 'classification' has 2 unique values: ['ckd' 'notckd']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in cat_col:
    # encoder = LabelEncoder()
    df[col] = df[col].fillna(df[col].mode()[0])
    # df[col] = encoder.fit_transform(df[col])

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], color='blue', kde=True)
plt.title('Dist of age')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
sns.histplot(df['bp'], color='blue')


plt.subplot(2, 2, 2)
sns.kdeplot(df['bp'])
plt.title('')
plt.show()

# %%
# there are upto 120 have 80 bp

# %%
df['htn']
# Out:
# 0      yes
# 1       no
# 2       no
# 3      yes
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: htn, Length: 400, dtype: object

# %%
sns.countplot(x=df['htn'], palette='Set2')
plt.xlabel('Hypertension')
plt.ylabel('Frequency')
plt.title('Hypertension')
plt.show()
# Out:
# C:\Users\Anshil\AppData\Local\Temp\ipykernel_15544\1510294496.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['htn'], palette='Set2')

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
# Determine the age of the person who is suffering from high blood pressure

# %%
df.groupby('bp')['age'].count().sort_values(ascending=False)
# Out:
# bp
# 80.0     115
# 70.0     107
# 60.0      70
# 90.0      52
# 100.0     24
# 50.0       5
# 110.0      3
# 120.0      1
# 140.0      1
# 180.0      1
# Name: age, dtype: int64

# %%
# there are 1 person suffering from high blood pressue

# %%
# graphical presentaion of blood pressure vs age relation
plt.figure(figsize=(10, 6))
sns.histplot(x='age', y='bp', data=df, hue='bp', palette='Set2')
plt.xlabel('Age', fontsize=14)
plt.ylabel('Blood Presure', fontsize=14)
plt.title('B.p. VS Age Analysis', fontsize=20)
plt.show()

# %%
# blood presure problem are causing upto 60 years old person

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.countplot(x=df['ane'], palette='cool')
plt.xlabel('Anemia', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.title('Anemia Cuases to..', fontsize=20)
plt.show()
# Out:
# C:\Users\Anshil\AppData\Local\Temp\ipykernel_15544\4102644357.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['ane'], palette='cool')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[151], line 2
#       1 sns.countplot(x=df['ane'], palette='cool')
# ----> 2 plt.xlabel('Anemia', frequency=14)
#       3 plt.title('Anemia Cuases to..', fontsize=20)
#       4 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:4135, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4126 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4127 def xlabel(
#    4128     xlabel: str,
#    (...)
#    4133     **kwargs,
#    4134 ) -> Text:
# -> 4135     return gca().set_xlabel(
#    4136         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4137     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_base.py:3481, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3474     x = {
#    3475         'left': 0,
#    3476         'center': 0.5,
#    3477         'right': 1,
#    3478     }[loc]
#    3479     kwargs.update(x=x, horizontalalignment=loc)
# -> 3481 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axis.py:1823, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1821 if fontdict is not None:
#    1822     self.label.update(fontdict)
# -> 1823 self.label.update(kwargs)
#    1824 self.stale = True
#    1825 return self.label
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\artist.py:1209, in Artist.update(self, props)
#    1201 def update(self, props):
#    1202     """
#    1203     Update this artist's properties from the dict *props*.
#    1204
#    (...)
#    1207     props : dict
#    1208     """
# -> 1209     return self._update_props(
#    1210         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: 'Text' object has no property 'frequency'
