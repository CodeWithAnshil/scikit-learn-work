# %% [markdown]
# # Project- Student Performance Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
df=pd.read_csv(r"data\StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Processing

# %%
df['avarage_score']=(df['math score']+df['reading score']+df['writing score'])/3
df['result']=df['avarage_score'].apply(lambda x:1 if x>=70 else 0)
df.head(50)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
le=LabelEncoder()
df['gender']=le.fit_transform(df['gender'])
df['race/ethnicity']=le.fit_transform(df['race/ethnicity'])
df['parental level of education']=le.fit_transform(df['parental level of education'])
df['lunch']=le.fit_transform(df['lunch'])
df['test preparation course']=le.fit_transform(df['test preparation course'])
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0               1                            1      1
# 1         0               2                            4      1
# 2         0               1                            3      1
# 3         1               0                            0      0
# 4         1               2                            4      1
# ..      ...             ...                          ...    ...
# 995       0               4                            3      1
# 996       1               2                            2      0
# 997       0               2                            2      0
# 998       0               3                            4      1
# 999       0               3                            4      0
#
#      test preparation course  math score  reading score  writing score  \
# 0                          1          72             72             74
# ...

# %% [markdown]
# # Feature and Label

# %%
X_class=df[['gender','race/ethnicity','parental level of education','lunch','test preparation course','math score','reading score']]
y_class=df['result']

# %% [markdown]
# # Train Test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_class,y_class,test_size=0.2,random_state=1)

# %%
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (800, 7) (800,)
# (200, 7) (200,)

# %% [markdown]
# # Train Model

# %%
model=LogisticRegression(max_iter=500)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %% [markdown]
# # Prediction

# %%
pred=model.predict(X_test)
print("Accuracy:",accuracy_score(y_test,pred))
print("\nClassification report\n",classification_report(y_test,pred))
# Out:
# Accuracy: 0.975
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       107
#            1       0.98      0.97      0.97        93
#
#     accuracy                           0.97       200
#    macro avg       0.98      0.97      0.97       200
# weighted avg       0.98      0.97      0.97       200

# %%
sns.countplot(x='result',data=df,hue='result',palette='cool')
plt.title("Pass and Fail graph")
plt.show()

# %%
X_reg=X_class
y_reg=df[["math score","reading score","writing score"]]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
import joblib

# %%
reg_model=MultiOutputRegressor(RandomForestRegressor())
reg_model.fit(X_reg,y_reg)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor())
